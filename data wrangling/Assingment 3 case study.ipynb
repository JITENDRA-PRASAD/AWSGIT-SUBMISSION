# %%
import ssl
import pandas as pd

# %%
import seaborn as sns

# %%
ssl._create_default_https_context = ssl._create_unverified_context

# %%
Url = 'https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'

# %%
df = pd.read_csv(Url)

# %%
df
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.shape[0]
# Out:
# 57394

# %%
df.shape[1]
# Out:
# 49

# %%
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
df['location'].nunique()
# Out:
# 216

# %%
df['continent'].value_counts()
# Out:
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: continent, dtype: int64

# %%
df['total_cases'].max()
# Out:
# 55154651.0

# %%
df['total_cases'].mean()
# Out:
# 167797.3688753302

# %%
df['total_deaths']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 57389    7.0
# 57390    7.0
# 57391    7.0
# 57392    7.0
# 57393    7.0
# Name: total_deaths, Length: 57394, dtype: float64

# %%
df['total_deaths'].quantile(0.25)
# Out:
# 13.0

# %%
df['total_deaths'].quantile(0.5)
# Out:
# 84.0

# %%
df['total_deaths'].quantile(0.75)
# Out:
# 727.0

# %%
df.sort_values(by='human_development_index')['continent'].head(1)
# Out:
# 37926    Africa
# Name: continent, dtype: object

# %%
df['continent'].value_counts()
# Out:
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: continent, dtype: int64

# %%
df['continent'][df['gdp_per_capita']==df['gdp_per_capita'].min()]
# Out:
# 10259    Africa
# 10260    Africa
# 10261    Africa
# 10262    Africa
# 10263    Africa
#           ...
# 10501    Africa
# 10502    Africa
# 10503    Africa
# 10504    Africa
# 10505    Africa
# Name: continent, Length: 247, dtype: object

# %%
new_df = df[['continent','location','date','total_cases','total_deaths','gdp_per_capita']]

# %%
new_df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita
# 0            1803.987
# 1            1803.987
# 2            1803.987
# 3            1803.987
# 4            1803.987
# ...

# %%
new_df_2 = df

# %%
new_df_2.drop_duplicates(subset=None)
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
new_df_2.isnull().sum()
# Out:
# iso_code                                323
# continent                               646
# location                                  0
# date                                      0
# total_cases                            3636
# new_cases                               929
# new_cases_smoothed                     1742
# total_deaths                          13026
# new_deaths                              929
# new_deaths_smoothed                    1742
# total_cases_per_million                3923
# new_cases_per_million                   993
# new_cases_smoothed_per_million         1807
# total_deaths_per_million              13298
# new_deaths_per_million                  993
# new_deaths_smoothed_per_million        1807
# reproduction_rate                     19698
# icu_patients                          52904
# icu_patients_per_million              52904
# hosp_patients                         52389
# hosp_patients_per_million             52389
# ...

# %%
new_df_2.dropna(subset=['continent'])
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# iso_code                                      object
# continent                                     object
# location                                      object
# date                                  datetime64[ns]
# total_cases                                  float64
# new_cases                                    float64
# new_cases_smoothed                           float64
# total_deaths                                 float64
# new_deaths                                   float64
# new_deaths_smoothed                          float64
# total_cases_per_million                      float64
# new_cases_per_million                        float64
# new_cases_smoothed_per_million               float64
# total_deaths_per_million                     float64
# new_deaths_per_million                       float64
# new_deaths_smoothed_per_million              float64
# reproduction_rate                            float64
# icu_patients                                 float64
# ...

# %%
df['month'] = df['date'].dt.month

# %%
df
# Out:
#       iso_code continent       location       date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan 2019-12-31          NaN        0.0
# 1          AFG      Asia    Afghanistan 2020-01-01          NaN        0.0
# 2          AFG      Asia    Afghanistan 2020-02-01          NaN        0.0
# 3          AFG      Asia    Afghanistan 2020-03-01          NaN        0.0
# 4          AFG      Asia    Afghanistan 2020-04-01          NaN        0.0
# ...        ...       ...            ...        ...          ...        ...
# 57389      NaN       NaN  International 2020-11-13        696.0        NaN
# 57390      NaN       NaN  International 2020-11-14        696.0        NaN
# 57391      NaN       NaN  International 2020-11-15        696.0        NaN
# 57392      NaN       NaN  International 2020-11-16        696.0        NaN
# 57393      NaN       NaN  International 2020-11-17        696.0        NaN
#
# ...

# %%
df.groupby('continent').max()
# Out:
#               iso_code                      location       date  total_cases  \
# continent
# Africa             ZWE                      Zimbabwe 2020-12-11     752269.0
# Asia               YEM                         Yemen 2020-12-11    8874290.0
# Europe             VAT                       Vatican 2020-12-11    1991233.0
# North America      VIR  United States Virgin Islands 2020-12-11   11205486.0
# Oceania            WLF             Wallis and Futuna 2020-12-11      27750.0
# South America      VEN                     Venezuela 2020-12-11    5876464.0
#
#                new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# continent
# Africa           13944.0           12583.714       20314.0       572.0
# Asia             97894.0           93198.571      130519.0      2003.0
# Europe           86852.0           54868.571       52147.0      2004.0
# North America   184813.0          156419.143      247220.0      4928.0
# ...

# %%
df_groupby = df.groupby('continent').max().reset_index()

# %%
df_groupby
# Out:
#        continent iso_code                      location       date  \
# 0         Africa      ZWE                      Zimbabwe 2020-12-11
# 1           Asia      YEM                         Yemen 2020-12-11
# 2         Europe      VAT                       Vatican 2020-12-11
# 3  North America      VIR  United States Virgin Islands 2020-12-11
# 4        Oceania      WLF             Wallis and Futuna 2020-12-11
# 5  South America      VEN                     Venezuela 2020-12-11
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %%
df_groupby['total_deaths_to_total_cases'] = df['total_deaths']/df['total_cases']

# %%
df_groupby
# Out:
#        continent iso_code                      location       date  \
# 0         Africa      ZWE                      Zimbabwe 2020-12-11
# 1           Asia      YEM                         Yemen 2020-12-11
# 2         Europe      VAT                       Vatican 2020-12-11
# 3  North America      VIR  United States Virgin Islands 2020-12-11
# 4        Oceania      WLF             Wallis and Futuna 2020-12-11
# 5  South America      VEN                     Venezuela 2020-12-11
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %%
df_groupby['gdp_per_capita']
# Out:
# 0     26382.287
# 1    116935.600
# 2     94277.965
# 3     54225.446
# 4     44648.710
# 5     22767.037
# Name: gdp_per_capita, dtype: float64

# %%
sns.distplot(df_groupby['gdp_per_capita'])
# Out:
# c:\users\prakash\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Density'>

# %%
sns.jointplot(data=df_groupby , x = 'total_cases' , y = 'gdp_per_capita' , kind='scatter')

# %%
sns.catplot(data=df_groupby, x='continent',y='total_cases' , kind = 'bar')

# %%
df_groupby.to_csv('groupby.csv', index=False)

# %%
# command is correct but it runing continonusly so i stop this forcefully thats why i get error

# %%
sns.pairplot(data = df_groupby)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-5e9c702af3c7> in <module>
# ----> 1 sns.pairplot(df_groupby)
#
# c:\users\prakash\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\prakash\appdata\local\programs\python\python39\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1987     # Set up the PairGrid
#    1988     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 1989     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
# ...
